# %%
'''
    Importing Modules
'''
from keras.datasets import imdb
import numpy as np
from keras import models
from keras import layers
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
'''
    Loading Training and Test Data
'''
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = 10000)

# %%
'''
    We can't give NN a list of integers. So we create the following function to convert
    to tensors of shape (rows, 10000). We also simultaneously perform one-hot encoding.
'''
def vectorize_sequences(sequences, dim = 10000):
    results = np.zeros((len(sequences), dim))
    for i, sequence in enumerate (sequences):
        results[i, sequence] = 1
    return (results)

# %%
'''
    Applying the function to test and train data
'''
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
'''
    Vectorize the labels
'''
y_train = np.array(train_labels).astype('float32')
y_test = np.array(test_labels).astype('float32')

# %%
'''
    Network Architecture
'''
model = models.Sequential()
model.add(layers.Dense(16, activation = 'relu', input_shape = (10000,)))
model.add(layers.Dense(16, activation = 'relu'))
model.add(layers.Dense(1, activation = 'sigmoid'))

# %%
'''
    Specify loss function and optimizer
'''
model.compile(optimizer='rmsprop',
loss='binary_crossentropy',
metrics=['acc'])

# %%
'''
    Split train into validation and train
'''
x_val = x_train[0:10000]
x_partial_train = x_train[10000:]
y_val = y_train[0:10000]
y_partial_train = y_train[10000:]

# %%
'''
    Fit the data
'''
history = model.fit(x_partial_train, y_partial_train, epochs = 20, batch_size = 512, 
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 13s 868us/step - loss: 0.5231 - acc: 0.7947 - val_loss: 0.3922 - val_acc: 0.8738
# Epoch 2/20
# 15000/15000 [==============================] - 10s 674us/step - loss: 0.3151 - acc: 0.9023 - val_loss: 0.3086 - val_acc: 0.8881
# Epoch 3/20
# 15000/15000 [==============================] - 3s 167us/step - loss: 0.2321 - acc: 0.9256 - val_loss: 0.2830 - val_acc: 0.8887
# Epoch 4/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.1814 - acc: 0.9413 - val_loss: 0.2903 - val_acc: 0.8820
# Epoch 5/20
# 15000/15000 [==============================] - 2s 163us/step - loss: 0.1485 - acc: 0.9527 - val_loss: 0.2772 - val_acc: 0.8888
# Epoch 6/20
# 15000/15000 [==============================] - 2s 162us/step - loss: 0.1241 - acc: 0.9619 - val_loss: 0.2895 - val_acc: 0.8859
# Epoch 7/20
# 15000/15000 [==============================] - 2s 155us/step - loss: 0.1015 - acc: 0.9710 - val_loss: 0.3090 - val_acc: 0.8817
# Epoch 8/20
# 15000/15000 [==============================] - 2s 153us/step - loss: 0.0854 - acc: 0.9765 - val_loss: 0.3676 - val_acc: 0.8672
# Epoch 9/20
# 15000/15000 [==============================] - 2s 147us/step - loss: 0.0715 - acc: 0.9803 - val_loss: 0.3414 - val_acc: 0.8808
# Epoch 10/20
# 15000/15000 [==============================] - 2s 151us/step - loss: 0.0583 - acc: 0.9854 - val_loss: 0.3664 - val_acc: 0.8778
# Epoch 11/20
# 15000/15000 [==============================] - 2s 157us/step - loss: 0.0507 - acc: 0.9872 - val_loss: 0.3923 - val_acc: 0.8768
# Epoch 12/20
# 15000/15000 [==============================] - 2s 156us/step - loss: 0.0398 - acc: 0.9907 - val_loss: 0.4189 - val_acc: 0.8759
# Epoch 13/20
# 15000/15000 [==============================] - 3s 171us/step - loss: 0.0320 - acc: 0.9935 - val_loss: 0.4491 - val_acc: 0.8730
# Epoch 14/20
# 15000/15000 [==============================] - 2s 153us/step - loss: 0.0269 - acc: 0.9942 - val_loss: 0.4830 - val_acc: 0.8708
# Epoch 15/20
# 15000/15000 [==============================] - 2s 153us/step - loss: 0.0205 - acc: 0.9965 - val_loss: 0.5151 - val_acc: 0.8697
# Epoch 16/20
# 15000/15000 [==============================] - 2s 158us/step - loss: 0.0154 - acc: 0.9982 - val_loss: 0.5727 - val_acc: 0.8625
# Epoch 17/20
# 15000/15000 [==============================] - 2s 154us/step - loss: 0.0141 - acc: 0.9984 - val_loss: 0.5778 - val_acc: 0.8687
# Epoch 18/20
# 15000/15000 [==============================] - 3s 169us/step - loss: 0.0117 - acc: 0.9983 - val_loss: 0.6132 - val_acc: 0.8672
# Epoch 19/20
# 15000/15000 [==============================] - 2s 149us/step - loss: 0.0065 - acc: 0.9998 - val_loss: 0.7219 - val_acc: 0.8595
# Epoch 20/20
# 15000/15000 [==============================] - 2s 160us/step - loss: 0.0095 - acc: 0.9983 - val_loss: 0.6794 - val_acc: 0.8648

# %%
'''
    Looking at the result
'''
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
'''
    Plotting training and validation loss by epoch
'''
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']

epoch = np.arange(1, 21)
plt.plot(epoch, train_loss, 'b', label = 'Training Loss')
plt.plot(epoch, val_loss, 'r', label = 'Validation Loss')
plt.xlabel('Epoch Count')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Vs Epoch for Training and Validation')
# Out:
# Text(0.5, 1.0, 'Loss Vs Epoch for Training and Validation')

# %%
'''
    Plotting training and validation accuracy by epoch
'''
train_acc= history_dict['acc']
val_acc = history_dict['val_acc']

epoch = np.arange(1, 21)
plt.plot(epoch, train_acc, 'b', label = 'Training Accuracy')
plt.plot(epoch, val_acc, 'r', label = 'Validation Accuracy')
plt.xlabel('Epoch Count')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuaracy Vs Epoch for Training and Validation')
# Out:
# Text(0.5, 1.0, 'Accuaracy Vs Epoch for Training and Validation')

# %%
'''
    We will set number of epochs to be about 4 and retrain the model and predict on test data
'''
model.fit(x_train, y_train, epochs = 4, batch_size = 512)
# Out:
# Epoch 1/4
# 25000/25000 [==============================] - 3s 116us/step - loss: 0.2262 - acc: 0.9461
# Epoch 2/4
# 25000/25000 [==============================] - 3s 109us/step - loss: 0.1396 - acc: 0.9592
# Epoch 3/4
# 25000/25000 [==============================] - 3s 107us/step - loss: 0.1116 - acc: 0.9666
# Epoch 4/4
# 25000/25000 [==============================] - 3s 120us/step - loss: 0.0876 - acc: 0.9734

# %%
'''
    We achieve an accuracy of roughly 85%. Not bad 
'''
results = model.evaluate(x_test, y_test)
results
# Out:
# 25000/25000 [==============================] - 6s 230us/step
# [0.49114053478717806, 0.859279990196228]
